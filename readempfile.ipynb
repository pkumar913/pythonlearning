# %%
import pandas as pd

df = pd.read_csv("employee.csv")

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        age          workclass  fnlwgt    education  educational-num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
# display first 10 rows
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  educational-num  \
# 0   39          State-gov   77516   Bachelors               13
# 1   50   Self-emp-not-inc   83311   Bachelors               13
# 2   38            Private  215646     HS-grad                9
# 3   53            Private  234721        11th                7
# 4   28            Private  338409   Bachelors               13
# 5   37            Private  284582     Masters               14
# 6   49            Private  160187         9th                5
# 7   52   Self-emp-not-inc  209642     HS-grad                9
# 8   31            Private   45781     Masters               14
# 9   42            Private  159449   Bachelors               13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
# display first 5 rows
df.head()
# Out:
#    age          workclass  fnlwgt   education  educational-num  \
# 0   39          State-gov   77516   Bachelors               13
# 1   50   Self-emp-not-inc   83311   Bachelors               13
# 2   38            Private  215646     HS-grad                9
# 3   53            Private  234721        11th                7
# 4   28            Private  338409   Bachelors               13
#
#         marital-status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %%
# display last 10 lines
df.tail(10)
# Out:
#        age      workclass  fnlwgt      education  educational-num  \
# 32551   32        Private   34066           10th                6
# 32552   43        Private   84661      Assoc-voc               11
# 32553   32        Private  116138        Masters               14
# 32554   53        Private  321865        Masters               14
# 32555   22        Private  310152   Some-college               10
# 32556   27        Private  257302     Assoc-acdm               12
# 32557   40        Private  154374        HS-grad                9
# 32558   58        Private  151910        HS-grad                9
# 32559   22        Private  201490        HS-grad                9
# 32560   52   Self-emp-inc  287927        HS-grad                9
#
#             marital-status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# ...

# %%
# display information about dataframes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1   workclass        32561 non-null  object
#  2   fnlwgt           32561 non-null  int64
#  3   education        32561 non-null  object
#  4   educational-num  32561 non-null  int64
#  5   marital-status   32561 non-null  object
#  6   occupation       32561 non-null  object
#  7   relationship     32561 non-null  object
#  8   race             32561 non-null  object
#  9   gender           32561 non-null  object
#  10  capital-gain     32561 non-null  int64
#  11  capital-loss     32561 non-null  int64
#  12  hours-per-week   32561 non-null  int64
#  13  native-country   32561 non-null  object
#  14  income           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#display datatypes
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
# defaulting to numerical columns only
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  32561.000000  3.256100e+04     32561.000000  32561.000000
# mean      38.581647  1.897784e+05        10.080679   1077.648844
# std       13.640433  1.055500e+05         2.572720   7385.292085
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.178270e+05         9.000000      0.000000
# 50%       37.000000  1.783560e+05        10.000000      0.000000
# 75%       48.000000  2.370510e+05        12.000000      0.000000
# max       90.000000  1.484705e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  32561.000000    32561.000000
# mean      87.303830       40.437456
# std      402.960219       12.347429
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   32561.000000     32561  3.256100e+04     32561     32561.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     22696           NaN     10501              NaN
# mean       38.581647       NaN  1.897784e+05       NaN        10.080679
# std        13.640433       NaN  1.055500e+05       NaN         2.572720
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN        10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN        12.000000
# max        90.000000       NaN  1.484705e+06       NaN        16.000000
#
#              marital-status       occupation relationship    race gender  \
# ...

# %%
#display only particular column
df['workclass']
# Out:
# 0                State-gov
# 1         Self-emp-not-inc
# 2                  Private
# 3                  Private
# 4                  Private
#                ...
# 32556              Private
# 32557              Private
# 32558              Private
# 32559              Private
# 32560         Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
# display multiple columns
df[['workclass', 'education', 'age']]
# Out:
#                workclass    education  age
# 0              State-gov    Bachelors   39
# 1       Self-emp-not-inc    Bachelors   50
# 2                Private      HS-grad   38
# 3                Private         11th   53
# 4                Private    Bachelors   28
# ...                  ...          ...  ...
# 32556            Private   Assoc-acdm   27
# 32557            Private      HS-grad   40
# 32558            Private      HS-grad   58
# 32559            Private      HS-grad   22
# 32560       Self-emp-inc      HS-grad   52
#
# [32561 rows x 3 columns]

# %%
# output filter data to new file
df['workclass'].to_csv('finaloutput.csv')

# %%
# output the df based on condition
cond = df['workclass'] == ' Private'
df[cond]
# Out:
#        age workclass  fnlwgt      education  educational-num  \
# 2       38   Private  215646        HS-grad                9
# 3       53   Private  234721           11th                7
# 4       28   Private  338409      Bachelors               13
# 5       37   Private  284582        Masters               14
# 6       49   Private  160187            9th                5
# ...    ...       ...     ...            ...              ...
# 32555   22   Private  310152   Some-college               10
# 32556   27   Private  257302     Assoc-acdm               12
# 32557   40   Private  154374        HS-grad                9
# 32558   58   Private  151910        HS-grad                9
# 32559   22   Private  201490        HS-grad                9
#
#                marital-status          occupation    relationship    race  \
# 2                    Divorced   Handlers-cleaners   Not-in-family   White
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
cond = df['workclass'].str.strip() == 'Private'
df[cond]
# Out:
#        age workclass  fnlwgt      education  educational-num  \
# 2       38   Private  215646        HS-grad                9
# 3       53   Private  234721           11th                7
# 4       28   Private  338409      Bachelors               13
# 5       37   Private  284582        Masters               14
# 6       49   Private  160187            9th                5
# ...    ...       ...     ...            ...              ...
# 32555   22   Private  310152   Some-college               10
# 32556   27   Private  257302     Assoc-acdm               12
# 32557   40   Private  154374        HS-grad                9
# 32558   58   Private  151910        HS-grad                9
# 32559   22   Private  201490        HS-grad                9
#
#                marital-status          occupation    relationship    race  \
# 2                    Divorced   Handlers-cleaners   Not-in-family   White
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
df[df['workclass'].str.strip() == 'Private']
# Out:
#        age workclass  fnlwgt      education  educational-num  \
# 2       38   Private  215646        HS-grad                9
# 3       53   Private  234721           11th                7
# 4       28   Private  338409      Bachelors               13
# 5       37   Private  284582        Masters               14
# 6       49   Private  160187            9th                5
# ...    ...       ...     ...            ...              ...
# 32555   22   Private  310152   Some-college               10
# 32556   27   Private  257302     Assoc-acdm               12
# 32557   40   Private  154374        HS-grad                9
# 32558   58   Private  151910        HS-grad                9
# 32559   22   Private  201490        HS-grad                9
#
#                marital-status          occupation    relationship    race  \
# 2                    Divorced   Handlers-cleaners   Not-in-family   White
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
# multiple conditions
cond1 = df['workclass'].str.strip() == 'Private'
cond2 = df['education'] == ' Bachelors'
df[cond1 & cond2]
# Out:
#        age workclass  fnlwgt   education  educational-num  \
# 4       28   Private  338409   Bachelors               13
# 9       42   Private  159449   Bachelors               13
# 12      23   Private  122272   Bachelors               13
# 32      45   Private  386940   Bachelors               13
# 42      24   Private  172987   Bachelors               13
# ...    ...       ...     ...         ...              ...
# 32461   24   Private  284317   Bachelors               13
# 32507   50   Private  302372   Bachelors               13
# 32533   54   Private  337992   Bachelors               13
# 32536   34   Private  160216   Bachelors               13
# 32538   38   Private  139180   Bachelors               13
#
#             marital-status          occupation    relationship  \
# 4       Married-civ-spouse      Prof-specialty            Wife
# 9       Married-civ-spouse     Exec-managerial         Husband
# 12           Never-married        Adm-clerical       Own-child
# ...

# %%
# 3rd to 9th rows all the columns
df.iloc[3:10]
# Out:
#    age          workclass  fnlwgt   education  educational-num  \
# 3   53            Private  234721        11th                7
# 4   28            Private  338409   Bachelors               13
# 5   37            Private  284582     Masters               14
# 6   49            Private  160187         9th                5
# 7   52   Self-emp-not-inc  209642     HS-grad                9
# 8   31            Private   45781     Masters               14
# 9   42            Private  159449   Bachelors               13
#
#            marital-status          occupation    relationship    race  \
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
# get the 3rd to 9th row, 3rd to 7th columns
df.iloc[3:10, 3:7]
# Out:
#     education  educational-num          marital-status          occupation
# 3        11th                7      Married-civ-spouse   Handlers-cleaners
# 4   Bachelors               13      Married-civ-spouse      Prof-specialty
# 5     Masters               14      Married-civ-spouse     Exec-managerial
# 6         9th                5   Married-spouse-absent       Other-service
# 7     HS-grad                9      Married-civ-spouse     Exec-managerial
# 8     Masters               14           Never-married      Prof-specialty
# 9   Bachelors               13      Married-civ-spouse     Exec-managerial

# %%
#df.loc[rows, column]
df.loc[3:9]
# Out:
#    age          workclass  fnlwgt   education  educational-num  \
# 3   53            Private  234721        11th                7
# 4   28            Private  338409   Bachelors               13
# 5   37            Private  284582     Masters               14
# 6   49            Private  160187         9th                5
# 7   52   Self-emp-not-inc  209642     HS-grad                9
# 8   31            Private   45781     Masters               14
# 9   42            Private  159449   Bachelors               13
#
#            marital-status          occupation    relationship    race  \
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.loc[3:10, ["workclass", "education"]]
# Out:
#             workclass      education
# 3             Private           11th
# 4             Private      Bachelors
# 5             Private        Masters
# 6             Private            9th
# 7    Self-emp-not-inc        HS-grad
# 8             Private        Masters
# 9             Private      Bachelors
# 10            Private   Some-college

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.drop_duplicates() #will display all unique records
# Out:
#        age          workclass  fnlwgt    education  educational-num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop_duplicates().shape
# Out:
# (32537, 15)

# %%
#display all duplicated records only
df[df.duplicated]
# Out:
#        age          workclass  fnlwgt      education  educational-num  \
# 4881    25            Private  308144      Bachelors               13
# 5104    90            Private   52386   Some-college               10
# 9171    21            Private  250051   Some-college               10
# 11631   20            Private  107658   Some-college               10
# 13084   25            Private  195994        1st-4th                2
# 15059   21            Private  243368      Preschool                1
# 17040   46            Private  173243        HS-grad                9
# 18555   30            Private  144593        HS-grad                9
# 18698   19            Private   97261        HS-grad                9
# 21318   19            Private  138153   Some-college               10
# 21490   19            Private  146679   Some-college               10
# 21875   49            Private   31267        7th-8th                4
# ...

# %%
#sorting the df based on age in ascending order
df.sort_values('age')
# Out:
#        age          workclass  fnlwgt      education  educational-num  \
# 12318   17            Private  127366           11th                7
# 6312    17            Private  132755           11th                7
# 30927   17            Private  108470           11th                7
# 12787   17          Local-gov  308901           11th                7
# 25755   17                  ?   47407           11th                7
# ...    ...                ...     ...            ...              ...
# 24043   90   Self-emp-not-inc   82628        HS-grad                9
# 32277   90            Private  313749        HS-grad                9
# 5104    90            Private   52386   Some-college               10
# 8963    90                  ?   77053        HS-grad                9
# 10210   90   Self-emp-not-inc  282095   Some-college               10
#
#             marital-status        occupation    relationship  \
# 12318        Never-married             Sales       Own-child
# ...

# %%
# sort dataframe with age in descending order
df.sort_values('age', ascending=False)
# Out:
#        age workclass  fnlwgt   education  educational-num  \
# 5406    90   Private   51744     Masters               14
# 6624    90   Private  313986        11th                7
# 20610   90   Private  206667     Masters               14
# 1040    90   Private  137018     HS-grad                9
# 1935    90   Private  221832   Bachelors               13
# ...    ...       ...     ...         ...              ...
# 609     17   Private  169658        10th                6
# 22928   17         ?  332666        10th                6
# 19190   17   Private   29571        12th                8
# 19206   17   Private  183066        10th                6
# 24954   17   Private  160968        11th                7
#
#             marital-status          occupation    relationship    race  \
# 5406         Never-married     Exec-managerial   Not-in-family   Black
# 6624    Married-civ-spouse        Craft-repair         Husband   White
# ...
